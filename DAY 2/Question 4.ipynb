# %% [markdown]
# ## Tuple and explore default methods.

# %%
tup = (1, 2, 3, 4, 5, 1, 1, 2, 3, 4, 1, 2 )

# %%
tup
# Out:
# (1, 2, 3, 4, 5, 1, 1, 2, 3, 4, 1, 2)

# %% [markdown]
# ### count()

# %%
# count() used to count number occurance

tup.count(1)
# Out:
# 4

# %%
tup.count(2)
# Out:
# 3

# %% [markdown]
# ### index()

# %%
# index() used to return index value

tup.index(5)
# Out:
# 4
