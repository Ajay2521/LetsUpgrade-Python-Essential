# %% [markdown]
# ## Strings and explore default methods.

# %%
str = "ajay m"

# %%
str
# Out:
# 'ajay m'

# %% [markdown]
# ### capitalize()

# %%
# capitalize() used Converts the first character to upper case.

str.capitalize()
# Out:
# 'Ajay m'

# %% [markdown]
# ### encode()

# %%
# encode() used to return an encoded version of the string

str.encode()
# Out:
# b'ajay m'

# %% [markdown]
# ### isalpha()

# %%
# isalpha() used to return ture is all the character in the string is alphabet.

str.isalpha()
# Out:
# False

# %% [markdown]
# ### upper()

# %%
# upper() used to convert into upper case

str.upper()
# Out:
# 'AJAY M'

# %% [markdown]
# ### lower()

# %%
# lower() used to convert into lower case

str.lower()
# Out:
# 'ajay m'

# %% [markdown]
# ### isprintable()

# %%
# isprintable() used to return true if characters in the string are printable

str.isprintable()
# Out:
# True
